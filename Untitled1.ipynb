# %%
import json
from pycocotools.coco import COCO
from sklearn.preprocessing import LabelEncoder

# %%
J = json.loads(open('/media/i008/ssd500/annotations/instances_val2017.json').read())

# J['annotations'][:20]

# %%
coco = COCO('/media/i008/ssd500/annotations/instances_val2017.json')
coco
# Out:
# loading annotations into memory...
# Done (t=0.31s)
# creating index...
# index created!

# %%
k = json.loads(open('newcoco.json','r').read())

# %%
= COCO('newcoco.json')
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!

# %%
self.ids[index]
ann_ids = coco.getAnnIds(imgIds=img_id)
target = coco.loadAnns(ann_ids)
# Out:
# {171142: {'segmentation': [[155.06,
#     134.83,
#     155.06,
#     78.37,
#     173.6,
#     52.25,
#     193.82,
#     39.61,
#     268.82,
#     38.76,
#     269.66,
#     143.26,
#     200.56,
#     152.53,
#     160.96,
#     152.53]],
#   'area': 11952.5691,
#   'iscrowd': 0,
#   'image_id': 464476,
#   'bbox': [155.06, 38.76, 114.6, 113.77],
#   'category_id': 2,
#   'id': 171142},
#  172226: {'segmentation': [[444.22,
#     100.4,
#     588.62,
#     82.52,
#     587.24,
#     303.94,
#     424.96,
#     236.55,
#     423.59,
#     184.29,
#     423.59,
#     176.04,
#     438.71,
#     173.29,
#     440.09,
#     163.66,
#     441.47,
#     138.9]],
#   'area': 27792.233200000002,
#   'iscrowd': 0,
#   'image_id': 492937,
#   'bbox': [423.59, 82.52, 165.03, 221.42],
#   'category_id': 2,
#   'id': 172226},
#  175488: {'segmentation': [[237.22,
#     178.23,
#     215.25,
#     177.95,
#     214.14,
#     174.33,
#     195.79,
#     176.0,
#     193.56,
#     179.06,
# ...

# %%
img_id = bla.imgs.keys()
ann_ids = bla.getAnnIds(imgIds=img_id)

# %%
len(list(coco.imgs.keys()))
J = json.loads(open('/media/i008/ssd500/annotations/instances_val2017.json').read())
len([a for a in J['annotations'] if a['image_id'] == ids[0]])
# Out:
# 19

# %%
ids = list(coco.imgs.keys())

# %%
ids[0]
# Out:
# 397133
