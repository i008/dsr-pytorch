# %% [markdown]
# # additional questions
# (can be done on notebook 5 fashion-mnist)
# - Perform error analysiss and visualization on the fmnist dataset.
# - Use pytorch advanced scheduling in the fmnist example( check notebook)
# - Create a sampler that makes batches of random 10,000 samples does not take the whole thing. Basically making them shorter (as we did int sneaker-non-sneaker)
# - Implement imgaug in the sneaker-not-sneaker project
# - Implement neptune.ml tracking for one of the project (fashionmnist)

# %%
from torchvision.models import resnet50

# %%
resnet = resnet50()
from torchsummary import torchsummary

a = list(resnet.named_childrena())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c6177433719d> in <module>()
#       2 from torchsummary import torchsummary
#       3
# ----> 4 a = list(resnet.named_childrena())
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     533                 return modules[name]
#     534         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 535             type(self).__name__, name))
#     536
#     537     def __setattr__(self, name, value):
#
# AttributeError: 'ResNet' object has no attribute 'named_childrena'

# %%
a[0]
# Out:
# ('', ResNet(
#    (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#    (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (relu): ReLU(inplace)
#    (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#    (layer1): Sequential(
#      (0): Bottleneck(
#        (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (relu): ReLU(inplace)
#        (downsample): Sequential(
# ...
